# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import cv2
import pandas as pd

# %% [markdown]
# ##### Meta Data

# %%
meta_data = pd.read_csv('data/HAM10000_metadata.csv')
meta_data
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %% [markdown]
# ##### Diagnosis Distributions

# %%
sns.countplot(x=meta_data['dx'], order=meta_data['dx'].value_counts().index)
plt.show()
print(meta_data['dx'].value_counts())
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %% [markdown]
# ##### Diagnosis Type Distributions

# %%
sns.countplot(x=meta_data['dx_type'], order=meta_data['dx_type'].value_counts().index)
plt.show()
print(meta_data['dx_type'].value_counts())
# Out:
# dx_type
# histo        5340
# follow_up    3704
# consensus     902
# confocal       69
# Name: count, dtype: int64

# %% [markdown]
# ##### Sex Distributions

# %%
sns.countplot(x=meta_data['sex'], order=meta_data['sex'].value_counts().index)
plt.show()
print(meta_data['sex'].value_counts())
# Out:
# sex
# male       5406
# female     4552
# unknown      57
# Name: count, dtype: int64

# %% [markdown]
# ##### Localization

# %%
plot = sns.countplot(x=meta_data['localization'], order=meta_data['localization'].value_counts().index)
plot.set_xticklabels(plot.get_xticklabels(), rotation=40, ha='right')
plt.show()
print(meta_data['localization'].value_counts())
# Out:
# localization
# back               2192
# lower extremity    2077
# trunk              1404
# upper extremity    1118
# abdomen            1022
# face                745
# chest               407
# foot                319
# unknown             234
# neck                168
# scalp               128
# hand                 90
# ear                  56
# genital              48
# acral                 7
# Name: count, dtype: int64

# %% [markdown]
# ##### Age Distributions

# %%
plot = sns.relplot(data=meta_data['age'])
plt.show()
print(meta_data['age'].value_counts())
# Out:
# age
# 45.0    1299
# 50.0    1187
# 55.0    1009
# 40.0     985
# 60.0     803
# 70.0     756
# 35.0     753
# 65.0     731
# 75.0     618
# 30.0     464
# 80.0     404
# 85.0     290
# 25.0     247
# 20.0     169
# 5.0       86
# 15.0      77
# 10.0      41
# 0.0       39
# Name: count, dtype: int64
